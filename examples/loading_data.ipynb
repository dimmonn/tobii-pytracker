# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from tobii_pytracker.analyze.data_loader import DataLoader
from tobii_pytracker.configs.custom_config import CustomConfig

config = CustomConfig('../configs/config.yaml')
loader = DataLoader(config, root='../')

# %%
loader.get_subjects()[-5:]
# Out:
# ['20260820_194424']

# %%
loader.get_subject_data(loader.get_subjects()[-1])
# Out:
#                                 screenshot_file  \
# 0  output/20260820_194424/frame_35_delay-1s.gif
# 1  output/20260820_194424/frame_42_delay-1s.gif
# 2  output/20260820_194424/frame_09_delay-1s.gif
# 3  output/20260820_194424/frame_34_delay-1s.gif
# 4  output/20260820_194424/frame_26_delay-1s.gif
# 5  output/20260820_194424/frame_37_delay-1s.gif
# 6  output/20260820_194424/frame_28_delay-1s.gif
# 7  output/20260820_194424/frame_30_delay-1s.gif
# 8  output/20260820_194424/frame_31_delay-1s.gif
# 9  output/20260820_194424/frame_57_delay-1s.gif
#
#                                     input_data classification  \
# 0  ./datasets/chess/good/frame_35_delay-1s.gif          chess
# 1   ./datasets/chess/bad/frame_42_delay-1s.gif          chess
# 2  ./datasets/chess/good/frame_09_delay-1s.gif          chess
# 3  ./datasets/chess/good/frame_34_delay-1s.gif          chess
# 4  ./datasets/chess/good/frame_26_delay-1s.gif          chess
# 5  ./datasets/chess/good/frame_37_delay-1s.gif          chess
# 6  ./datasets/chess/good/frame_28_delay-1s.gif          chess
# 7  ./datasets/chess/good/frame_30_delay-1s.gif          chess
# 8  ./datasets/chess/good/frame_31_delay-1s.gif          chess
# 9   ./datasets/chess/bad/frame_57_delay-1s.gif          chess
#
#   user_classification                                          gaze_data  \
# 0               chess  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 1               chess  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 2               chess  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 3               chess  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 4               chess  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 5               chess  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 6               chess  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 7               chess  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 8               chess  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 9               chess  [{'event_type': 'MonocularEyeSampleEventNT', '...
#
#                                       objects_bboxes  voice_file  \
# 0  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 1  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 2  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 3  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 4  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 5  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 6  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 7  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 8  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 9  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
#
#    voice_start_timestamp
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).head()
# Out:
#           set_name  slide_index                               screenshot_file  \
# 0  20260820_194424            0  output/20260820_194424/frame_35_delay-1s.gif
# 1  20260820_194424            0  output/20260820_194424/frame_35_delay-1s.gif
# 2  20260820_194424            0  output/20260820_194424/frame_35_delay-1s.gif
# 3  20260820_194424            0  output/20260820_194424/frame_35_delay-1s.gif
# 4  20260820_194424            0  output/20260820_194424/frame_35_delay-1s.gif
#
#                                     input_data classification  \
# 0  ./datasets/chess/good/frame_35_delay-1s.gif          chess
# 1  ./datasets/chess/good/frame_35_delay-1s.gif          chess
# 2  ./datasets/chess/good/frame_35_delay-1s.gif          chess
# 3  ./datasets/chess/good/frame_35_delay-1s.gif          chess
# 4  ./datasets/chess/good/frame_35_delay-1s.gif          chess
#
#   user_classification model_prediction  \
# 0               chess             None
# 1               chess             None
# 2               chess             None
# 3               chess             None
# 4               chess             None
#
#                                       objects_bboxes  voice_file  \
# 0  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 1  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 2  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 3  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 4  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
#
#    voice_start_timestamp  ... system_time  gaze_x_left  gaze_y_left  \
# 0                    NaN  ...   41.639413   296.757812   306.300781
# 1                    NaN  ...   41.659997   296.757812   306.058594
# 2                    NaN  ...   41.680518   296.140625   303.363281
# 3                    NaN  ...   41.701054   295.175781   300.503906
# 4                    NaN  ...   41.721513   293.089844   294.257812
#
#    gaze_x_right  gaze_y_right  pupil_left pupil_right  avg_gaze_x  avg_gaze_y  \
# 0          None          None           5           0  296.757812  306.300781
# 1          None          None           5           0  296.757812  306.058594
# 2          None          None           5           0  296.140625  303.363281
# 3          None          None           5           0  295.175781  300.503906
# 4          None          None           5           0  293.089844  294.257812
#
#    avg_pupil_size
# 0             2.5
# 1             2.5
# 2             2.5
# 3             2.5
# 4             2.5
#
# [5 rows x 23 columns]

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).tail()
# Out:
#            set_name  slide_index  \
# 79  20260820_194424            0
# 80  20260820_194424            0
# 81  20260820_194424            0
# 82  20260820_194424            0
# 83  20260820_194424            0
#
#                                  screenshot_file  \
# 79  output/20260820_194424/frame_35_delay-1s.gif
# 80  output/20260820_194424/frame_35_delay-1s.gif
# 81  output/20260820_194424/frame_35_delay-1s.gif
# 82  output/20260820_194424/frame_35_delay-1s.gif
# 83  output/20260820_194424/frame_35_delay-1s.gif
#
#                                      input_data classification  \
# 79  ./datasets/chess/good/frame_35_delay-1s.gif          chess
# 80  ./datasets/chess/good/frame_35_delay-1s.gif          chess
# 81  ./datasets/chess/good/frame_35_delay-1s.gif          chess
# 82  ./datasets/chess/good/frame_35_delay-1s.gif          chess
# 83  ./datasets/chess/good/frame_35_delay-1s.gif          chess
#
#    user_classification model_prediction  \
# 79               chess             None
# 80               chess             None
# 81               chess             None
# 82               chess             None
# 83               chess             None
#
#                                        objects_bboxes  voice_file  \
# 79  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 80  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 81  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 82  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 83  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
#
#     voice_start_timestamp  ... system_time  gaze_x_left  gaze_y_left  \
# 79                    NaN  ...   43.796706  -280.941406  -325.175781
# 80                    NaN  ...   43.817260  -281.992188  -326.238281
# 81                    NaN  ...   43.837785  -281.992188  -326.480469
# 82                    NaN  ...   43.858321  -281.992188  -326.480469
# 83                    NaN  ...   43.878843  -281.992188  -326.480469
#
#     gaze_x_right  gaze_y_right  pupil_left pupil_right  avg_gaze_x  \
# 79          None          None           5           0 -280.941406
# 80          None          None           5           0 -281.992188
# 81          None          None           5           0 -281.992188
# 82          None          None           5           0 -281.992188
# 83          None          None           5           0 -281.992188
#
#     avg_gaze_y  avg_pupil_size
# 79 -325.175781             2.5
# 80 -326.238281             2.5
# 81 -326.480469             2.5
# 82 -326.480469             2.5
# 83 -326.480469             2.5
#
# [5 rows x 23 columns]

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).shape
# Out:
# (84, 23)

# %%
loader.get_subject_data(loader.get_subjects()[-1])['gaze_data'][0]
# Out:
# "[{'event_type': 'MonocularEyeSampleEventNT', 'event_id': 481, 'logged_time': 41.62732220833438, 'system_time': 41.639413124999976, 'gaze_x_left': 296.7578125, 'gaze_y_left': 306.30078125, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 296.7578125, 'avg_gaze_y': 306.30078125, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 485, 'logged_time': 41.64732220833438, 'system_time': 41.659997375000046, 'gaze_x_left': 296.7578125, 'gaze_y_left': 306.05859375, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 296.7578125, 'avg_gaze_y': 306.05859375, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 489, 'logged_time': 41.66732220833438, 'system_time': 41.68051791666659, 'gaze_x_left': 296.140625, 'gaze_y_left': 303.36328125, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 296.140625, 'avg_gaze_y': 303.36328125, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 492, 'logged_time': 41.687322208334386, 'system_time': 41.70105383333333, 'gaze_x_left': 295.17578125, 'gaze_y_left': 300.50390625, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 295.17578125, 'avg_gaze_y': 300.50390625, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 496, 'logged_time': 41.70732220833439, 'system_time': 41.72151254166664, 'gaze_x_left': 293.08984375, 'gaze_y_left': 294.2578125, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 293.08984375, 'avg_gaze_y': 294.2578125, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 500, 'logged_time': 41.72732220833439, 'system_time': 41.74199658333333, 'gaze_x_left': 290.9609375, 'gaze_y_left': 287.51953125, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 290.9609375, 'avg_gaze_y': 287.51953125, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 503, 'logged_time': 41.747322208334396, 'system_time': 41.76252866666658, 'gaze_x_left': 289.83203125, 'gaze_y_left': 281.83984375, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 289.83203125, 'avg_gaze_y': 281.83984375, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 520, 'logged_time': 41.82732220833441, 'system_time': 41.844944916666634, 'gaze_x_left': 281.31640625, 'gaze_y_left': 258.70703125, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 281.31640625, 'avg_gaze_y': 258.70703125, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 523, 'logged_time': 41.84732220833441, 'system_time': 41.85524712499995, 'gaze_x_left': 276.16015625, 'gaze_y_left': 251.83984375, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 276.16015625, 'avg_gaze_y': 251.83984375, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 527, 'logged_time': 41.867322208334414, 'system_time': 41.87573245833329, 'gaze_x_left': 269.1796875, 'gaze_y_left': 242.828125, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 269.1796875, 'avg_gaze_y': 242.828125, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 530, 'logged_time': 41.88732220833442, 'system_time': 41.89634133333328, 'gaze_x_left': 264.515625, 'gaze_y_left': 238.171875, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 264.515625, 'avg_gaze_y': 238.171875, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 534, 'logged_time': 41.90732220833442, 'system_time': 41.91686283333337, 'gaze_x_left': 257.14453125, 'gaze_y_left': 229.59375, 'gaze_x_right': None, 'gaze_ ...

# %%
loader = DataLoader(config, root='../')
loader.plot_gaze(loader.get_subjects()[-1], 0, gradient=True, flip_y=True)

# %%
loader.get_subject_data(loader.get_subjects()[-1])
# Out:
#                                 screenshot_file  \
# 0  output/20260820_194424/frame_35_delay-1s.gif
# 1  output/20260820_194424/frame_42_delay-1s.gif
# 2  output/20260820_194424/frame_09_delay-1s.gif
# 3  output/20260820_194424/frame_34_delay-1s.gif
# 4  output/20260820_194424/frame_26_delay-1s.gif
# 5  output/20260820_194424/frame_37_delay-1s.gif
# 6  output/20260820_194424/frame_28_delay-1s.gif
# 7  output/20260820_194424/frame_30_delay-1s.gif
# 8  output/20260820_194424/frame_31_delay-1s.gif
# 9  output/20260820_194424/frame_57_delay-1s.gif
#
#                                     input_data classification  \
# 0  ./datasets/chess/good/frame_35_delay-1s.gif          chess
# 1   ./datasets/chess/bad/frame_42_delay-1s.gif          chess
# 2  ./datasets/chess/good/frame_09_delay-1s.gif          chess
# 3  ./datasets/chess/good/frame_34_delay-1s.gif          chess
# 4  ./datasets/chess/good/frame_26_delay-1s.gif          chess
# 5  ./datasets/chess/good/frame_37_delay-1s.gif          chess
# 6  ./datasets/chess/good/frame_28_delay-1s.gif          chess
# 7  ./datasets/chess/good/frame_30_delay-1s.gif          chess
# 8  ./datasets/chess/good/frame_31_delay-1s.gif          chess
# 9   ./datasets/chess/bad/frame_57_delay-1s.gif          chess
#
#   user_classification                                          gaze_data  \
# 0               chess  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 1               chess  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 2               chess  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 3               chess  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 4               chess  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 5               chess  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 6               chess  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 7               chess  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 8               chess  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 9               chess  [{'event_type': 'MonocularEyeSampleEventNT', '...
#
#                                       objects_bboxes  voice_file  \
# 0  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 1  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 2  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 3  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 4  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 5  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 6  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 7  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 8  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 9  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
#
#    voice_start_timestamp
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).head().columns
# Out:
# Index(['set_name', 'slide_index', 'screenshot_file', 'input_data',
#        'classification', 'user_classification', 'model_prediction',
#        'objects_bboxes', 'voice_file', 'voice_start_timestamp', 'event_type',
#        'event_id', 'logged_time', 'system_time', 'gaze_x_left', 'gaze_y_left',
#        'gaze_x_right', 'gaze_y_right', 'pupil_left', 'pupil_right',
#        'avg_gaze_x', 'avg_gaze_y', 'avg_pupil_size'],
#       dtype='object')

# %% [markdown]
# # Visualize gaze falling into bounding boxes (Time series only)

# %%
# from pathlib import Path
# from tobii_pytracker.analyze.data_loader import DataLoader
# from tobii_pytracker.analyze.models import BBoxTimeSeriesAnalyzer
# from tobii_pytracker.configs.custom_config import CustomConfig
#
# config = globals().get("config")
# if config is None:
#     config = CustomConfig("../configs/config.yaml")
#
# loader = globals().get("loader")
# if loader is None:
#     loader = DataLoader(config, root="../")
#
# set_name = loader.get_subjects()[-1]
# slide_index = 0
# slide_data = loader.get_slide_data(set_name, slide_index, flatten=True)
#
# analyzer = BBoxTimeSeriesAnalyzer(output_folder=Path("../output"))
# scored = analyzer.analyze(slide_data, set_name=set_name, slide_index=slide_index)
# scored[["bbox_index", "channel_idx", "hit_count", "is_visited"]]
#
# analyzer.plot_analysis(
#     slide_data=slide_data,
#     scored_bboxes=scored,
#     set_name=set_name,
#     slide_index=slide_index,
#     area_x=config.get_area_of_interest_size()[0],
#     area_y=config.get_area_of_interest_size()[1],
#     show=True,
# )

# %% [markdown]
# # Visualize gaze falling into bounding boxes (Images only)

# %%
from pathlib import Path
from tobii_pytracker.analyze.data_loader import DataLoader
from tobii_pytracker.analyze.models import BBoxAttentionAnalyzer
from tobii_pytracker.configs.custom_config import CustomConfig

config = globals().get("config")
if config is None:
    config = CustomConfig("../configs/config.yaml")

loader = globals().get("loader")
if loader is None:
    loader = DataLoader(config, root="../")

set_name = loader.get_subjects()[-1]
slide_index = 0
slide_data = loader.get_slide_data(set_name, slide_index, flatten=True)

raw_data = (
    slide_data[["set_name", "slide_index", "objects_bboxes"]]
    .groupby(["set_name", "slide_index"], as_index=False)
    .agg({"objects_bboxes": "first"})
)

analyzer = BBoxAttentionAnalyzer(output_folder=Path("../output"))
scored = analyzer.analyze(raw_data=raw_data, gaze_data=slide_data)
scored[["bbox_index", "hit_count", "hit_gaze_indices", "coverage", "dwell_time","attention_score","attention_rank"]].head()

screenshot_rel = slide_data.iloc[0]["screenshot_file"]
screenshot_path = Path("../") / Path(str(screenshot_rel).replace("\\", "/"))

analyzer.plot_analysis(
    scored_bboxes=scored,
    gaze_data=slide_data,
    screenshot_path=screenshot_path,
    set_name=set_name,
    slide_index=slide_index,
    title="Image bounding boxes visited by gaze",
    top_k=50,
    min_hits=1,
    show_gaze=True,
    show=True,
)
# Out:
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'Image bounding boxes visited by gaze'}>)

# %% [markdown]
# # Visualize gaze falling into bounding boxes (Text only)

# %%
# from pathlib import Path
# from tobii_pytracker.analyze.data_loader import DataLoader
# from tobii_pytracker.analyze.models import BBoxTextAnalyzer
# from tobii_pytracker.configs.custom_config import CustomConfig
#
# config = globals().get("config")
# if config is None:
#     config = CustomConfig("../configs/config.yaml")
#
# loader = globals().get("loader")
# if loader is None:
#     loader = DataLoader(config, root="../")
#
# set_name = loader.get_subjects()[-1]
# slide_index = 0
# slide_data = loader.get_slide_data(set_name, slide_index, flatten=True)
#
# analyzer = BBoxTextAnalyzer(output_folder=Path("../output"))
# scored = analyzer.analyze(
#     slide_data,
#     level="words",
#     set_name=set_name,
#     slide_index=slide_index,
# )
# scored[["bbox_index", "text", "hit_count", "is_visited"]].head()
#
# analyzer.plot_analysis(
#     slide_data=slide_data,
#     level="words",
#     scored_bboxes=scored,
#     set_name=set_name,
#     slide_index=slide_index,
#     area_x=config.get_area_of_interest_size()[0],
#     area_y=config.get_area_of_interest_size()[1],
#     show=True,
# )
# Out:
# (<Figure size 1400x700 with 1 Axes>,
#  <Axes: title={'center': 'Text with gaze-visited bounding boxes'}, xlabel='Center-origin x (px)', ylabel='Center-origin y (px)'>)
