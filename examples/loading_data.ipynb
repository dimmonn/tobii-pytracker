# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# [autoreload of tobii_pytracker.analyze.bbox.geometry failed: Traceback (most recent call last):
#   File "/Users/dima/miniconda3/envs/tobii-pytracker/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/dima/miniconda3/envs/tobii-pytracker/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Users/dima/miniconda3/envs/tobii-pytracker/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/dima/tobii/tobii-pytracker/src/tobii_pytracker/analyze/bbox/geometry.py", line 3, in <module>
#     from parsing import bbox_contains_gaze
# ModuleNotFoundError: No module named 'parsing'
# ]
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from tobii_pytracker.analyze.data_loader import DataLoader
from tobii_pytracker.configs.custom_config import CustomConfig

config = CustomConfig('../configs/config.yaml')
loader = DataLoader(config, root='../')

# %%
loader.get_subjects()[-5:]
# Out:
# ['20260915_115512']

# %%
loader.get_subject_data(loader.get_subjects()[-1])
# Out:
#                                screenshot_file  \
# 0               output/20260915_115512/cat.jpg
# 1    output/20260915_115512/vintage-trains.jpg
# 2  output/20260915_115512/chickago-traffic.jpg
#
#                                  input_data classification  \
# 0               datasets/varia/cats/cat.jpg           cats
# 1  datasets/varia/trains/vintage-trains.jpg         trains
# 2  datasets/varia/cars/chickago-traffic.jpg           cars
#
#   user_classification                                          gaze_data  \
# 0                cats  [{'event_type': 'BinocularEyeSampleEventNT', '...
# 1              trains  [{'event_type': 'BinocularEyeSampleEventNT', '...
# 2                cars  [{'event_type': 'BinocularEyeSampleEventNT', '...
#
#                                       objects_bboxes  \
# 0  {'image_bboxes': [{'class': 'grid', 'conf': 1....
# 1  {'image_bboxes': [{'class': 'grid', 'conf': 1....
# 2  {'image_bboxes': [{'class': 'grid', 'conf': 1....
#
#                              voice_file  voice_start_timestamp
# 0  output/20260915_115512/voice_000.wav                13.1596
# 1  output/20260915_115512/voice_001.wav                39.7771
# 2  output/20260915_115512/voice_002.wav                71.7670

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).head()
# Out:
#           set_name  slide_index                 screenshot_file  \
# 0  20260915_115512            0  output/20260915_115512/cat.jpg
# 1  20260915_115512            0  output/20260915_115512/cat.jpg
# 2  20260915_115512            0  output/20260915_115512/cat.jpg
# 3  20260915_115512            0  output/20260915_115512/cat.jpg
# 4  20260915_115512            0  output/20260915_115512/cat.jpg
#
#                     input_data classification user_classification  \
# 0  datasets/varia/cats/cat.jpg           cats                cats
# 1  datasets/varia/cats/cat.jpg           cats                cats
# 2  datasets/varia/cats/cat.jpg           cats                cats
# 3  datasets/varia/cats/cat.jpg           cats                cats
# 4  datasets/varia/cats/cat.jpg           cats                cats
#
#   model_prediction                                     objects_bboxes  \
# 0             None  {'image_bboxes': [{'class': 'grid', 'conf': 1....
# 1             None  {'image_bboxes': [{'class': 'grid', 'conf': 1....
# 2             None  {'image_bboxes': [{'class': 'grid', 'conf': 1....
# 3             None  {'image_bboxes': [{'class': 'grid', 'conf': 1....
# 4             None  {'image_bboxes': [{'class': 'grid', 'conf': 1....
#
#                              voice_file  voice_start_timestamp  ...  \
# 0  output/20260915_115512/voice_000.wav                13.1596  ...
# 1  output/20260915_115512/voice_000.wav                13.1596  ...
# 2  output/20260915_115512/voice_000.wav                13.1596  ...
# 3  output/20260915_115512/voice_000.wav                13.1596  ...
# 4  output/20260915_115512/voice_000.wav                13.1596  ...
#
#   system_time  gaze_x_left  gaze_y_left  gaze_x_right  gaze_y_right  \
# 0   13.164156    94.490891   -53.613210     76.511192    -91.858649
# 1   13.164156    83.322601   -53.889441     68.252907    -89.781904
# 2   13.164156    88.030472   -55.203366     78.403587    -79.540229
# 3   13.164156    90.477333   -48.576736     77.799454    -79.496527
# 4   13.164156    90.288048   -59.167027     70.863991    -81.523633
#
#    pupil_left  pupil_right  avg_gaze_x  avg_gaze_y  avg_pupil_size
# 0    3.639633     3.553268   85.501041  -72.735929        3.596451
# 1    3.653671     3.562180   75.787754  -71.835673        3.607925
# 2    3.655731     3.563019   83.217030  -67.371798        3.609375
# 3    3.659637     3.556168   84.138393  -64.036632        3.607903
# 4    3.700821     3.557632   80.576019  -70.345330        3.629227
#
# [5 rows x 23 columns]

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).tail()
# Out:
#              set_name  slide_index                 screenshot_file  \
# 1540  20260915_115512            0  output/20260915_115512/cat.jpg
# 1541  20260915_115512            0  output/20260915_115512/cat.jpg
# 1542  20260915_115512            0  output/20260915_115512/cat.jpg
# 1543  20260915_115512            0  output/20260915_115512/cat.jpg
# 1544  20260915_115512            0  output/20260915_115512/cat.jpg
#
#                        input_data classification user_classification  \
# 1540  datasets/varia/cats/cat.jpg           cats                cats
# 1541  datasets/varia/cats/cat.jpg           cats                cats
# 1542  datasets/varia/cats/cat.jpg           cats                cats
# 1543  datasets/varia/cats/cat.jpg           cats                cats
# 1544  datasets/varia/cats/cat.jpg           cats                cats
#
#      model_prediction                                     objects_bboxes  \
# 1540             None  {'image_bboxes': [{'class': 'grid', 'conf': 1....
# 1541             None  {'image_bboxes': [{'class': 'grid', 'conf': 1....
# 1542             None  {'image_bboxes': [{'class': 'grid', 'conf': 1....
# 1543             None  {'image_bboxes': [{'class': 'grid', 'conf': 1....
# 1544             None  {'image_bboxes': [{'class': 'grid', 'conf': 1....
#
#                                 voice_file  voice_start_timestamp  ...  \
# 1540  output/20260915_115512/voice_000.wav                13.1596  ...
# 1541  output/20260915_115512/voice_000.wav                13.1596  ...
# 1542  output/20260915_115512/voice_000.wav                13.1596  ...
# 1543  output/20260915_115512/voice_000.wav                13.1596  ...
# 1544  output/20260915_115512/voice_000.wav                13.1596  ...
#
#      system_time  gaze_x_left  gaze_y_left  gaze_x_right  gaze_y_right  \
# 1540   35.998220  -117.494545   296.907878   -128.750954    288.161552
# 1541   36.014604  -116.410160   296.559012   -134.283314    287.297559
# 1542   36.033736  -113.652191   290.007091   -135.288563    287.337899
# 1543   36.059733  -122.392216   217.437422   -140.560913    219.586372
# 1544   36.059733  -180.964394  -151.352906   -211.602058   -162.249327
#
#       pupil_left  pupil_right  avg_gaze_x  avg_gaze_y  avg_pupil_size
# 1540    3.476578     3.404221 -123.122749  292.534715        3.440399
# 1541    3.479004     3.416458 -125.346737  291.928285        3.447731
# 1542    3.488907     3.420502 -124.470377  288.672495        3.454704
# 1543    3.484833     3.425385 -131.476564  218.511897        3.455109
# 1544    3.485733     3.424561 -196.283226 -156.801116        3.455147
#
# [5 rows x 23 columns]

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).shape
# Out:
# (1545, 23)

# %%
loader.get_subject_data(loader.get_subjects()[-1])['gaze_data'][0]
# Out:
# "[{'event_type': 'BinocularEyeSampleEventNT', 'event_id': 168, 'logged_time': 10.278520199994091, 'system_time': 13.164156399958301, 'gaze_x_left': 94.49089050292969, 'gaze_y_left': -53.61320972442627, 'gaze_x_right': 76.51119232177734, 'gaze_y_right': -91.85864925384521, 'pupil_left': 3.6396331787109375, 'pupil_right': 3.5532684326171875, 'avg_gaze_x': 85.50104141235352, 'avg_gaze_y': -72.73592948913574, 'avg_pupil_size': 3.5964508056640625}, {'event_type': 'BinocularEyeSampleEventNT', 'event_id': 169, 'logged_time': 10.29521549999481, 'system_time': 13.164156399958301, 'gaze_x_left': 83.32260131835938, 'gaze_y_left': -53.88944149017334, 'gaze_x_right': 68.2529067993164, 'gaze_y_right': -89.78190422058105, 'pupil_left': 3.6536712646484375, 'pupil_right': 3.5621795654296875, 'avg_gaze_x': 75.78775405883789, 'avg_gaze_y': -71.8356728553772, 'avg_pupil_size': 3.6079254150390625}, {'event_type': 'BinocularEyeSampleEventNT', 'event_id': 170, 'logged_time': 10.31140189996222, 'system_time': 13.164156399958301, 'gaze_x_left': 88.03047180175781, 'gaze_y_left': -55.20336627960205, 'gaze_x_right': 78.4035873413086, 'gaze_y_right': -79.54022884368896, 'pupil_left': 3.655731201171875, 'pupil_right': 3.563018798828125, 'avg_gaze_x': 83.2170295715332, 'avg_gaze_y': -67.37179756164551, 'avg_pupil_size': 3.609375}, {'event_type': 'BinocularEyeSampleEventNT', 'event_id': 171, 'logged_time': 10.330801899952348, 'system_time': 13.164156399958301, 'gaze_x_left': 90.47733306884766, 'gaze_y_left': -48.57673645019531, 'gaze_x_right': 77.79945373535156, 'gaze_y_right': -79.49652671813965, 'pupil_left': 3.659637451171875, 'pupil_right': 3.5561676025390625, 'avg_gaze_x': 84.13839340209961, 'avg_gaze_y': -64.03663158416748, 'avg_pupil_size': 3.6079025268554688}, {'event_type': 'BinocularEyeSampleEventNT', 'event_id': 172, 'logged_time': 10.345333299948834, 'system_time': 13.164156399958301, 'gaze_x_left': 90.28804779052734, 'gaze_y_left': -59.16702747344971, 'gaze_x_right': 70.8639907836914, 'gaze_y_right': -81.52363300323486, 'pupil_left': 3.7008209228515625, 'pupil_right': 3.5576324462890625, 'avg_gaze_x': 80.57601928710938, 'avg_gaze_y': -70.34533023834229, 'avg_pupil_size': 3.6292266845703125}, {'event_type': 'BinocularEyeSampleEventNT', 'event_id': 173, 'logged_time': 10.361351899977308, 'system_time': 13.164156399958301, 'gaze_x_left': 102.50507354736328, 'gaze_y_left': -55.76162338256836, 'gaze_x_right': 78.86260986328125, 'gaze_y_right': -73.17609786987305, 'pupil_left': 3.710357666015625, 'pupil_right': 3.5565948486328125, 'avg_gaze_x': 90.68384170532227, 'avg_gaze_y': -64.4688606262207, 'avg_pupil_size': 3.6334762573242188}, {'event_type': 'BinocularEyeSampleEventNT', 'event_id': 174, 'logged_time': 10.378730099997483, 'system_time': 13.164156399958301, 'gaze_x_left': 67.9833984375, 'gaze_y_left': -47.399282455444336, 'gaze_x_right': 71.16954803466797, 'gaze_y_right': -62.89486885070801, 'pupil_left': 3.69427490234375, 'pupil_right': 3.562744140625, 'avg_gaze_x': 69.57647323608398, 'avg_gaze_y': -55.14707565307617, 'avg_pupil_size': 3.628509521484375}, {'event_type': 'BinocularEyeSampleEventNT', 'event_id': 175, 'logged_time': 10.394811899983324, 'system_time': 13.164156399958301, 'gaze_x_left': -8.27911376953125, 'gaze_y_left': -7.992267608642578, 'gaze_x_right': -0.39516448974609375, 'gaze_y_right': -21.980738639831543, 'pupil_left': 3.7165679931640625, 'pupil_right': 3.5738677978515625, 'avg_gaze_x': -4.337139129638672, 'avg_gaze_y': -14.98650312423706, 'avg_pupil_size': 3.6452178955078125}, {'event_type': 'BinocularEyeSampleEventNT', 'event_id': 176, 'logged_time': 10.410541399964131, 'system_time': 13.164156399958301, 'gaze_x_left': 22.9046630859375, 'gaze_y_left': -10.284948348999023, 'gaze_x_right': 10.514259338378906, 'gaze_y_right': -22.700929641723633, 'pupil_left': 3.715850830078125, 'pupil_right': 3.5697479248046875, 'avg_gaze_x': 16.709461212158203, 'avg_gaze_y': -16.492938995361328, 'avg_pupil_size': 3.6427993774414062}, {'event ...

# %%
loader = DataLoader(config, root='../')
loader.plot_gaze(loader.get_subjects()[-1], 0, gradient=True, flip_y=True)

# %%
loader.get_subject_data(loader.get_subjects()[-1])
# Out:
#                                screenshot_file  \
# 0               output/20260915_115512/cat.jpg
# 1    output/20260915_115512/vintage-trains.jpg
# 2  output/20260915_115512/chickago-traffic.jpg
#
#                                  input_data classification  \
# 0               datasets/varia/cats/cat.jpg           cats
# 1  datasets/varia/trains/vintage-trains.jpg         trains
# 2  datasets/varia/cars/chickago-traffic.jpg           cars
#
#   user_classification                                          gaze_data  \
# 0                cats  [{'event_type': 'BinocularEyeSampleEventNT', '...
# 1              trains  [{'event_type': 'BinocularEyeSampleEventNT', '...
# 2                cars  [{'event_type': 'BinocularEyeSampleEventNT', '...
#
#                                       objects_bboxes  \
# 0  {'image_bboxes': [{'class': 'grid', 'conf': 1....
# 1  {'image_bboxes': [{'class': 'grid', 'conf': 1....
# 2  {'image_bboxes': [{'class': 'grid', 'conf': 1....
#
#                              voice_file  voice_start_timestamp
# 0  output/20260915_115512/voice_000.wav                13.1596
# 1  output/20260915_115512/voice_001.wav                39.7771
# 2  output/20260915_115512/voice_002.wav                71.7670

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).head().columns
# Out:
# Index(['set_name', 'slide_index', 'screenshot_file', 'input_data',
#        'classification', 'user_classification', 'model_prediction',
#        'objects_bboxes', 'voice_file', 'voice_start_timestamp', 'event_type',
#        'event_id', 'logged_time', 'system_time', 'gaze_x_left', 'gaze_y_left',
#        'gaze_x_right', 'gaze_y_right', 'pupil_left', 'pupil_right',
#        'avg_gaze_x', 'avg_gaze_y', 'avg_pupil_size'],
#       dtype='object')

# %% [markdown]
# # Visualize gaze falling into bounding boxes (Time series only)

# %%
from pathlib import Path
from tobii_pytracker.analyze.data_loader import DataLoader
from tobii_pytracker.analyze.models import BBoxTimeSeriesAnalyzer
from tobii_pytracker.configs.custom_config import CustomConfig

loader = DataLoader(config, root="../")
slide_data = loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True)
analyzer = BBoxTimeSeriesAnalyzer(
    output_folder=Path("../output/"),
    data=slide_data,
    config=CustomConfig("../configs/config.yaml")
)
analysis_results = analyzer.analyze()
analyzer.plot_analysis(analysis_results)

# %% [markdown]
# # Visualize gaze falling into bounding boxes (Images only)

# %%
from pathlib import Path
from tobii_pytracker.analyze.models import BBoxImagesAnalyzer
from tobii_pytracker.configs.custom_config import CustomConfig
from tobii_pytracker.analyze.data_loader import DataLoader

loader = DataLoader(config, root="../")

slide_data = loader.get_slide_data(
    loader.get_subjects()[-1],
    0,
    flatten=True,
)

analyzer = BBoxImagesAnalyzer(
    output_folder=Path("../output/"),
    data=slide_data,
    config=CustomConfig("../configs/config.yaml")
)
analysis_results = analyzer.analyze()
analyzer.plot_analysis(analysis_results)
# Out:
# Image: /Users/dima/tobii/tobii-pytracker/output/20260915_115512/cat.jpg
# Number of superpixel bounding boxes: 9
# Number of gaze-visited bounding boxes: 7
# Visited bbox indices: [0, 1, 2, 3, 4, 6, 7]

# %% [markdown]
# # Visualize gaze falling into bounding boxes (Text only)

# %%
from pathlib import Path
from tobii_pytracker.analyze.models import BBoxTextAnalyzer
from tobii_pytracker.analyze.data_loader import DataLoader
from tobii_pytracker.configs.custom_config import CustomConfig

loader = DataLoader(config, root="../")
slide_data = loader.get_slide_data(
    loader.get_subjects()[-1],
    0,
    flatten=True,
)
analyzer = BBoxTextAnalyzer(
    output_folder=Path("../output/"),
    data=slide_data,
    config=CustomConfig("../configs/config.yaml")
)
analysis_results = analyzer.analyze()
analyzer.plot_analysis(analysis_results)
