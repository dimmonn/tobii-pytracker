# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from tobii_pytracker.analyze.data_loader import DataLoader
from tobii_pytracker.configs.custom_config import CustomConfig

config = CustomConfig('../configs/config.yaml')
loader = DataLoader(config, root='../')

# %%
loader.get_subjects()[-5:]
# Out:
# ['20260712_201106']

# %%
loader.get_subject_data(loader.get_subjects()[-1])
# Out:
#                                 screenshot_file  \
# 0  output/20260712_201106/frame_34_delay-1s.gif
# 1  output/20260712_201106/frame_09_delay-1s.gif
# 2  output/20260712_201106/frame_39_delay-1s.gif
# 3  output/20260712_201106/frame_36_delay-1s.gif
# 4  output/20260712_201106/frame_64_delay-3s.gif
# 5  output/20260712_201106/frame_40_delay-1s.gif
# 6  output/20260712_201106/frame_18_delay-1s.gif
# 7  output/20260712_201106/frame_01_delay-1s.gif
# 8  output/20260712_201106/frame_43_delay-1s.gif
# 9  output/20260712_201106/frame_42_delay-1s.gif
#
#                                   input_data classification  \
# 0  datasets/chess/good/frame_34_delay-1s.gif           good
# 1  datasets/chess/good/frame_09_delay-1s.gif           good
# 2  datasets/chess/good/frame_39_delay-1s.gif           good
# 3  datasets/chess/good/frame_36_delay-1s.gif           good
# 4   datasets/chess/bad/frame_64_delay-3s.gif            bad
# 5   datasets/chess/bad/frame_40_delay-1s.gif            bad
# 6  datasets/chess/good/frame_18_delay-1s.gif           good
# 7  datasets/chess/good/frame_01_delay-1s.gif           good
# 8   datasets/chess/bad/frame_43_delay-1s.gif            bad
# 9   datasets/chess/bad/frame_42_delay-1s.gif            bad
#
#   user_classification                                          gaze_data  \
# 0                good  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 1                 bad  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 2                 bad  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 3                none  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 4                 bad  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 5                 bad  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 6                 bad  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 7                 bad  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 8                 bad  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 9                 bad  [{'event_type': 'MonocularEyeSampleEventNT', '...
#
#                                       objects_bboxes  voice_file  \
# 0  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 1  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 2  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 3  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 4  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 5  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 6  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 7  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 8  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
# 9  {'image_bboxes': [{'class': 'superpixel', 'con...         NaN
#
#    voice_start_timestamp
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).head()
# Out:
#           set_name  slide_index                               screenshot_file  \
# 0  20260712_201106            0  output/20260712_201106/frame_34_delay-1s.gif
# 1  20260712_201106            0  output/20260712_201106/frame_34_delay-1s.gif
# 2  20260712_201106            0  output/20260712_201106/frame_34_delay-1s.gif
# 3  20260712_201106            0  output/20260712_201106/frame_34_delay-1s.gif
# 4  20260712_201106            0  output/20260712_201106/frame_34_delay-1s.gif
#
#                                   input_data classification  \
# 0  datasets/chess/good/frame_34_delay-1s.gif           good
# 1  datasets/chess/good/frame_34_delay-1s.gif           good
# 2  datasets/chess/good/frame_34_delay-1s.gif           good
# 3  datasets/chess/good/frame_34_delay-1s.gif           good
# 4  datasets/chess/good/frame_34_delay-1s.gif           good
#
#   user_classification model_prediction  voice_file  voice_start_timestamp  \
# 0                good             None         NaN                    NaN
# 1                good             None         NaN                    NaN
# 2                good             None         NaN                    NaN
# 3                good             None         NaN                    NaN
# 4                good             None         NaN                    NaN
#
#                   event_type  ...  system_time  gaze_x_left  gaze_y_left  \
# 0  MonocularEyeSampleEventNT  ...    24.035081   194.183594   192.035156
# 1  MonocularEyeSampleEventNT  ...    24.055752   180.335938   201.679688
# 2  MonocularEyeSampleEventNT  ...    24.076338   169.066406   209.187500
# 3  MonocularEyeSampleEventNT  ...    24.097060   140.296875   221.882812
# 4  MonocularEyeSampleEventNT  ...    24.117772   104.863281   233.472656
#
#    gaze_x_right  gaze_y_right pupil_left pupil_right  avg_gaze_x  avg_gaze_y  \
# 0          None          None          5           0  194.183594  192.035156
# 1          None          None          5           0  180.335938  201.679688
# 2          None          None          5           0  169.066406  209.187500
# 3          None          None          5           0  140.296875  221.882812
# 4          None          None          5           0  104.863281  233.472656
#
#    avg_pupil_size
# 0             2.5
# 1             2.5
# 2             2.5
# 3             2.5
# 4             2.5
#
# [5 rows x 22 columns]

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).tail()
# Out:
#            set_name  slide_index  \
# 49  20260712_201106            0
# 50  20260712_201106            0
# 51  20260712_201106            0
# 52  20260712_201106            0
# 53  20260712_201106            0
#
#                                  screenshot_file  \
# 49  output/20260712_201106/frame_34_delay-1s.gif
# 50  output/20260712_201106/frame_34_delay-1s.gif
# 51  output/20260712_201106/frame_34_delay-1s.gif
# 52  output/20260712_201106/frame_34_delay-1s.gif
# 53  output/20260712_201106/frame_34_delay-1s.gif
#
#                                    input_data classification  \
# 49  datasets/chess/good/frame_34_delay-1s.gif           good
# 50  datasets/chess/good/frame_34_delay-1s.gif           good
# 51  datasets/chess/good/frame_34_delay-1s.gif           good
# 52  datasets/chess/good/frame_34_delay-1s.gif           good
# 53  datasets/chess/good/frame_34_delay-1s.gif           good
#
#    user_classification model_prediction  voice_file  voice_start_timestamp  \
# 49                good             None         NaN                    NaN
# 50                good             None         NaN                    NaN
# 51                good             None         NaN                    NaN
# 52                good             None         NaN                    NaN
# 53                good             None         NaN                    NaN
#
#                    event_type  ...  system_time  gaze_x_left  gaze_y_left  \
# 49  MonocularEyeSampleEventNT  ...    25.006513    56.753906   285.757812
# 50  MonocularEyeSampleEventNT  ...    25.027185    40.562500   285.789062
# 51  MonocularEyeSampleEventNT  ...    25.047841    28.664062   280.175781
# 52  MonocularEyeSampleEventNT  ...    25.068434    20.179688   269.429688
# 53  MonocularEyeSampleEventNT  ...    25.089039    16.097656   260.117188
#
#     gaze_x_right  gaze_y_right pupil_left pupil_right  avg_gaze_x  avg_gaze_y  \
# 49          None          None          5           0   56.753906  285.757812
# 50          None          None          5           0   40.562500  285.789062
# 51          None          None          5           0   28.664062  280.175781
# 52          None          None          5           0   20.179688  269.429688
# 53          None          None          5           0   16.097656  260.117188
#
#     avg_pupil_size
# 49             2.5
# 50             2.5
# 51             2.5
# 52             2.5
# 53             2.5
#
# [5 rows x 22 columns]

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).shape
# Out:
# (54, 22)

# %%
loader.get_subject_data(loader.get_subjects()[-1])['gaze_data'][0]
# Out:
# "[{'event_type': 'MonocularEyeSampleEventNT', 'event_id': 1728, 'logged_time': 24.023034624999013, 'system_time': 24.03508062499168, 'gaze_x_left': 194.18359375, 'gaze_y_left': 192.03515625, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 194.18359375, 'avg_gaze_y': 192.03515625, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 1734, 'logged_time': 24.043034624999013, 'system_time': 24.055751708321623, 'gaze_x_left': 180.3359375, 'gaze_y_left': 201.6796875, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 180.3359375, 'avg_gaze_y': 201.6796875, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 1737, 'logged_time': 24.063034624999013, 'system_time': 24.07633799999894, 'gaze_x_left': 169.06640625, 'gaze_y_left': 209.1875, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 169.06640625, 'avg_gaze_y': 209.1875, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 1743, 'logged_time': 24.083034624999012, 'system_time': 24.0970596249972, 'gaze_x_left': 140.296875, 'gaze_y_left': 221.8828125, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 140.296875, 'avg_gaze_y': 221.8828125, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 1751, 'logged_time': 24.10303462499901, 'system_time': 24.11777174999588, 'gaze_x_left': 104.86328125, 'gaze_y_left': 233.47265625, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 104.86328125, 'avg_gaze_y': 233.47265625, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 1756, 'logged_time': 24.12303462499901, 'system_time': 24.138557083322667, 'gaze_x_left': 84.85546875, 'gaze_y_left': 239.4765625, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 84.85546875, 'avg_gaze_y': 239.4765625, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 1762, 'logged_time': 24.14303462499901, 'system_time': 24.159292999989702, 'gaze_x_left': 49.5, 'gaze_y_left': 245.6015625, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 49.5, 'avg_gaze_y': 245.6015625, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 1767, 'logged_time': 24.16303462499901, 'system_time': 24.179995374986902, 'gaze_x_left': 24.9140625, 'gaze_y_left': 246.28515625, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': 24.9140625, 'avg_gaze_y': 246.28515625, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 1773, 'logged_time': 24.18303462499901, 'system_time': 24.20071783332969, 'gaze_x_left': -8.15234375, 'gaze_y_left': 246.2890625, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -8.15234375, 'avg_gaze_y': 246.2890625, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 1781, 'logged_time': 24.20303462499901, 'system_time': 24.221412249986315, 'gaze_x_left': -38.92578125, 'gaze_y_left': 240.28125, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -38.92578125, 'avg_gaze_y': 240.28125, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 1786, 'logged_time': 24.22303462499901, 'system_time': 24.231759416667046, 'gaze_x_left': -61.22265625, 'gaze_y_left': 234.875, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -61.22265625, 'avg_gaze_y': 234.875, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 1792, 'logged_time': 24.24303462499901, 'system_time': 24.25239629166026, 'gaze_x_left': -93.01953125, 'gaze_y_left': 221.34765625, 'gaze_x_right': None, 'gaze_y_right': None, 'pup ...

# %%
loader = DataLoader(config, root='../')
loader.plot_gaze(loader.get_subjects()[-1], 0, gradient=True, flip_y=True)
