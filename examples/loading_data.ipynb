# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from tobii_pytracker.analyze.data_loader import DataLoader
from tobii_pytracker.configs.custom_config import CustomConfig

config = CustomConfig('../configs/config.yaml')
loader = DataLoader(config, root='../')

# %%
loader.get_subjects()[-5:]
# Out:
# ['20260915_121156']

# %%
loader.get_subject_data(loader.get_subjects()[-1])
# Out:
#                          screenshot_file  \
# 0  output/20260915_121156/0.50205548.png
# 1   output/20260915_121156/0.1476469.png
# 2  output/20260915_121156/0.31664616.png
#
#                                           input_data classification  \
# 0  [ 0.54216265  0.72238348  1.4288852   2.136515...       abnormal
# 1  [ 0.8046684   0.36777149  0.24389371  0.026613...         normal
# 2  [ 0.24319908  0.37047144  1.0637381   1.678187...       abnormal
#
#   user_classification                                          gaze_data  \
# 0              normal  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 1            abnormal  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 2              normal  [{'event_type': 'MonocularEyeSampleEventNT', '...
#
#                                       objects_bboxes  voice_file  \
# 0  {'timeseries_bboxes': [{'channel_idx': 0, 'cha...         NaN
# 1  {'timeseries_bboxes': [{'channel_idx': 0, 'cha...         NaN
# 2  {'timeseries_bboxes': [{'channel_idx': 0, 'cha...         NaN
#
#    voice_start_timestamp
# 0                    NaN
# 1                    NaN
# 2                    NaN

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).head()
# Out:
#           set_name  slide_index                        screenshot_file  \
# 0  20260915_121156            0  output/20260915_121156/0.50205548.png
# 1  20260915_121156            0  output/20260915_121156/0.50205548.png
# 2  20260915_121156            0  output/20260915_121156/0.50205548.png
# 3  20260915_121156            0  output/20260915_121156/0.50205548.png
# 4  20260915_121156            0  output/20260915_121156/0.50205548.png
#
#                                           input_data classification  \
# 0  [ 0.54216265  0.72238348  1.4288852   2.136515...       abnormal
# 1  [ 0.54216265  0.72238348  1.4288852   2.136515...       abnormal
# 2  [ 0.54216265  0.72238348  1.4288852   2.136515...       abnormal
# 3  [ 0.54216265  0.72238348  1.4288852   2.136515...       abnormal
# 4  [ 0.54216265  0.72238348  1.4288852   2.136515...       abnormal
#
#   user_classification model_prediction  \
# 0              normal             None
# 1              normal             None
# 2              normal             None
# 3              normal             None
# 4              normal             None
#
#                                       objects_bboxes  voice_file  \
# 0  {'timeseries_bboxes': [{'channel_idx': 0, 'cha...         NaN
# 1  {'timeseries_bboxes': [{'channel_idx': 0, 'cha...         NaN
# 2  {'timeseries_bboxes': [{'channel_idx': 0, 'cha...         NaN
# 3  {'timeseries_bboxes': [{'channel_idx': 0, 'cha...         NaN
# 4  {'timeseries_bboxes': [{'channel_idx': 0, 'cha...         NaN
#
#    voice_start_timestamp  ... system_time  gaze_x_left  gaze_y_left  \
# 0                    NaN  ...   12.932720       -197.0        -80.0
# 1                    NaN  ...   12.946948       -197.0        -80.0
# 2                    NaN  ...   12.977045       -197.0        -80.0
# 3                    NaN  ...   12.994437       -196.0        -80.0
# 4                    NaN  ...   13.011395       -194.0        -80.0
#
#    gaze_x_right  gaze_y_right  pupil_left pupil_right avg_gaze_x  avg_gaze_y  \
# 0          None          None           5           0     -197.0       -80.0
# 1          None          None           5           0     -197.0       -80.0
# 2          None          None           5           0     -197.0       -80.0
# 3          None          None           5           0     -196.0       -80.0
# 4          None          None           5           0     -194.0       -80.0
#
#    avg_pupil_size
# 0             2.5
# 1             2.5
# 2             2.5
# 3             2.5
# 4             2.5
#
# [5 rows x 23 columns]

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).tail()
# Out:
#             set_name  slide_index                        screenshot_file  \
# 248  20260915_121156            0  output/20260915_121156/0.50205548.png
# 249  20260915_121156            0  output/20260915_121156/0.50205548.png
# 250  20260915_121156            0  output/20260915_121156/0.50205548.png
# 251  20260915_121156            0  output/20260915_121156/0.50205548.png
# 252  20260915_121156            0  output/20260915_121156/0.50205548.png
#
#                                             input_data classification  \
# 248  [ 0.54216265  0.72238348  1.4288852   2.136515...       abnormal
# 249  [ 0.54216265  0.72238348  1.4288852   2.136515...       abnormal
# 250  [ 0.54216265  0.72238348  1.4288852   2.136515...       abnormal
# 251  [ 0.54216265  0.72238348  1.4288852   2.136515...       abnormal
# 252  [ 0.54216265  0.72238348  1.4288852   2.136515...       abnormal
#
#     user_classification model_prediction  \
# 248              normal             None
# 249              normal             None
# 250              normal             None
# 251              normal             None
# 252              normal             None
#
#                                         objects_bboxes  voice_file  \
# 248  {'timeseries_bboxes': [{'channel_idx': 0, 'cha...         NaN
# 249  {'timeseries_bboxes': [{'channel_idx': 0, 'cha...         NaN
# 250  {'timeseries_bboxes': [{'channel_idx': 0, 'cha...         NaN
# 251  {'timeseries_bboxes': [{'channel_idx': 0, 'cha...         NaN
# 252  {'timeseries_bboxes': [{'channel_idx': 0, 'cha...         NaN
#
#      voice_start_timestamp  ... system_time  gaze_x_left  gaze_y_left  \
# 248                    NaN  ...   17.893111        -36.0       -330.0
# 249                    NaN  ...   17.908936        -36.0       -330.0
# 250                    NaN  ...   17.940213        -36.0       -330.0
# 251                    NaN  ...   17.957321        -36.0       -330.0
# 252                    NaN  ...   17.973516        -36.0       -330.0
#
#      gaze_x_right  gaze_y_right  pupil_left pupil_right avg_gaze_x  \
# 248          None          None           5           0      -36.0
# 249          None          None           5           0      -36.0
# 250          None          None           5           0      -36.0
# 251          None          None           5           0      -36.0
# 252          None          None           5           0      -36.0
#
#      avg_gaze_y  avg_pupil_size
# 248      -330.0             2.5
# 249      -330.0             2.5
# 250      -330.0             2.5
# 251      -330.0             2.5
# 252      -330.0             2.5
#
# [5 rows x 23 columns]

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).shape
# Out:
# (253, 23)

# %%
loader.get_subject_data(loader.get_subjects()[-1])['gaze_data'][0]
# Out:
# "[{'event_type': 'MonocularEyeSampleEventNT', 'event_id': 469, 'logged_time': 12.925024400032022, 'system_time': 12.932719600037672, 'gaze_x_left': -197.0, 'gaze_y_left': -80.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -197.0, 'avg_gaze_y': -80.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 473, 'logged_time': 12.945024400032022, 'system_time': 12.946948099997826, 'gaze_x_left': -197.0, 'gaze_y_left': -80.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -197.0, 'avg_gaze_y': -80.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 475, 'logged_time': 12.965024400032021, 'system_time': 12.977044500003103, 'gaze_x_left': -197.0, 'gaze_y_left': -80.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -197.0, 'avg_gaze_y': -80.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 476, 'logged_time': 12.985024400032021, 'system_time': 12.99443700001575, 'gaze_x_left': -196.0, 'gaze_y_left': -80.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -196.0, 'avg_gaze_y': -80.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 478, 'logged_time': 13.00502440003202, 'system_time': 13.011394900036976, 'gaze_x_left': -194.0, 'gaze_y_left': -80.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -194.0, 'avg_gaze_y': -80.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 480, 'logged_time': 13.02502440003202, 'system_time': 13.026608999993186, 'gaze_x_left': -194.0, 'gaze_y_left': -80.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -194.0, 'avg_gaze_y': -80.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 484, 'logged_time': 13.04502440003202, 'system_time': 13.059837400040124, 'gaze_x_left': -192.0, 'gaze_y_left': -80.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -192.0, 'avg_gaze_y': -80.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 485, 'logged_time': 13.06502440003202, 'system_time': 13.073699600005057, 'gaze_x_left': -191.0, 'gaze_y_left': -80.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -191.0, 'avg_gaze_y': -80.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 487, 'logged_time': 13.085024400032019, 'system_time': 13.089134500012733, 'gaze_x_left': -190.0, 'gaze_y_left': -82.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -190.0, 'avg_gaze_y': -82.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 491, 'logged_time': 13.105024400032018, 'system_time': 13.121079100004863, 'gaze_x_left': -189.0, 'gaze_y_left': -84.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -189.0, 'avg_gaze_y': -84.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 492, 'logged_time': 13.125024400032018, 'system_time': 13.137087600014638, 'gaze_x_left': -188.0, 'gaze_y_left': -85.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -188.0, 'avg_gaze_y': -85.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 494, 'logged_time': 13.145024400032018, 'system_time': 13.153756200044882, 'gaze_x_left': -187.0, 'gaze_y_left': -86.0, 'gaze_x_right': None, 'gaze_y_right': None, 'pupil_left': 5, 'pupil_right': 0, 'avg_gaze_x': -187.0, 'avg_gaze_y': -86.0, 'avg_pupil_size': 2.5}, {'event_type': 'MonocularEyeSampleEventNT', 'event_id': 496, 'logged_time': 13.165024400032017, 'system_time': 13.170195400016382, 'gaze_x_ ...

# %%
loader = DataLoader(config, root='../')
loader.plot_gaze(loader.get_subjects()[-1], 0, gradient=True, flip_y=True)

# %%
loader.get_subject_data(loader.get_subjects()[-1])
# Out:
#                          screenshot_file  \
# 0  output/20260915_121156/0.50205548.png
# 1   output/20260915_121156/0.1476469.png
# 2  output/20260915_121156/0.31664616.png
#
#                                           input_data classification  \
# 0  [ 0.54216265  0.72238348  1.4288852   2.136515...       abnormal
# 1  [ 0.8046684   0.36777149  0.24389371  0.026613...         normal
# 2  [ 0.24319908  0.37047144  1.0637381   1.678187...       abnormal
#
#   user_classification                                          gaze_data  \
# 0              normal  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 1            abnormal  [{'event_type': 'MonocularEyeSampleEventNT', '...
# 2              normal  [{'event_type': 'MonocularEyeSampleEventNT', '...
#
#                                       objects_bboxes  voice_file  \
# 0  {'timeseries_bboxes': [{'channel_idx': 0, 'cha...         NaN
# 1  {'timeseries_bboxes': [{'channel_idx': 0, 'cha...         NaN
# 2  {'timeseries_bboxes': [{'channel_idx': 0, 'cha...         NaN
#
#    voice_start_timestamp
# 0                    NaN
# 1                    NaN
# 2                    NaN

# %%
loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True).head().columns
# Out:
# Index(['set_name', 'slide_index', 'screenshot_file', 'input_data',
#        'classification', 'user_classification', 'model_prediction',
#        'objects_bboxes', 'voice_file', 'voice_start_timestamp', 'event_type',
#        'event_id', 'logged_time', 'system_time', 'gaze_x_left', 'gaze_y_left',
#        'gaze_x_right', 'gaze_y_right', 'pupil_left', 'pupil_right',
#        'avg_gaze_x', 'avg_gaze_y', 'avg_pupil_size'],
#       dtype='object')

# %% [markdown]
# # Visualize gaze falling into bounding boxes (Time series only)

# %%
from pathlib import Path
from tobii_pytracker.analyze.data_loader import DataLoader
from tobii_pytracker.analyze.models import BBoxTimeSeriesAnalyzer
from tobii_pytracker.configs.custom_config import CustomConfig

loader = DataLoader(config, root="../")
slide_data = loader.get_slide_data(loader.get_subjects()[-1], 0, flatten=True)
analyzer = BBoxTimeSeriesAnalyzer(
    output_folder=Path("../output/"),
    config=CustomConfig("../configs/config.yaml")
)
analysis_results = analyzer.analyze(background_data=slide_data)
analyzer.plot_analysis(analysis_results)

# %% [markdown]
# # Visualize gaze falling into bounding boxes (Images only)

# %%
from pathlib import Path
from tobii_pytracker.analyze.models import BBoxImagesAnalyzer
from tobii_pytracker.configs.custom_config import CustomConfig
from tobii_pytracker.analyze.data_loader import DataLoader

loader = DataLoader(config, root="../")

slide_data = loader.get_slide_data(
    loader.get_subjects()[-1],
    0,
    flatten=True,
)

analyzer = BBoxImagesAnalyzer(
    output_folder=Path("../output/"),
    config=CustomConfig("../configs/config.yaml")
)
analysis_results = analyzer.analyze(background_data=slide_data)
analyzer.plot_analysis(analysis_results)

# %% [markdown]
# # Visualize gaze falling into bounding boxes (Text only)

# %%
from pathlib import Path
from tobii_pytracker.analyze.models import BBoxTextAnalyzer
from tobii_pytracker.analyze.data_loader import DataLoader
from tobii_pytracker.configs.custom_config import CustomConfig

loader = DataLoader(config, root="../")
slide_data = loader.get_slide_data(
    loader.get_subjects()[-1],
    0,
    flatten=True,
)
analyzer = BBoxTextAnalyzer(
    output_folder=Path("../output/"),
    config=CustomConfig("../configs/config.yaml")
)
analysis_results = analyzer.analyze(background_data=slide_data)
analyzer.plot_analysis(analysis_results)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 16
#       7 slide_data = loader.get_slide_data(
#       8     loader.get_subjects()[-1],
#       9     0,
#      10     flatten=True,
#      11 )
#      12 analyzer = BBoxTextAnalyzer(
#      13     output_folder=Path("../output/"),
#      14     config=CustomConfig("../configs/config.yaml")
#      15 )
# ---> 16 analysis_results = analyzer.analyze(background_data=slide_data)
#      17 analyzer.plot_analysis(analysis_results)
#
# File ~/tobii/tobii-pytracker/src/tobii_pytracker/analyze/models.py:2451, in BBoxTextAnalyzer.analyze(self, background_data)
#    2446 text_bboxes = extract_text_bboxes(
#    2447     row["objects_bboxes"],
#    2448     level="words",
#    2449 )
#    2450 if not text_bboxes:
# -> 2451     raise ValueError(
#    2452         "No word bounding boxes were found in objects_bboxes."
#    2453     )
#    2454 gaze_x, gaze_y = extract_gaze_points(row, background_data)
#    2455 area_x, area_y = self.config.get_area_of_interest_size()
#
# ValueError: No word bounding boxes were found in objects_bboxes.
